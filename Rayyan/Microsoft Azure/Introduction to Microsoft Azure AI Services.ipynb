# %% [markdown]
# **Hour 01:-**
#
# Task 01:-
#
# (a) Decision
#
# (b) Language
#
# (c) Vision
#
# (d) OpenAI

# %% [markdown]
# Task 02:-
#
# (1) A single-service resource makes more sense because the startup has only one feature, keeping the system simpler, cheaper, and easier to develop and maintain.
#
# (2) A multi-service resource makes more sense because the app uses three different AI capabilities—sentiment analysis, image moderation, and speech-to-text—that can be managed and scaled independently.

# %% [markdown]
# **Hour 02:-**
#
# Task 01:-
#
# (a) Azure AI Vision
#
# (b) Custom Vision
#
# (c) Face
#
# (d) Video Indexer
#
# (e) Azure AI Vision

# %% [markdown]
# Task 02:-
#
# (1) Collecting images
#
# (2) Label the Defects
#
# (3) Train the custom Vision model
#
# (4) Train the model's accuracy
#
# (5) Deploy the trained model

# %% [markdown]
# Task 03:-
#
# Microsoft may restrict large-scale face identification more heavily because facial recognition involves sensitive biometric data and can create privacy, surveillance, bias, and misidentification risks, while general object detection usually identifies objects without directly identifying or tracking individual people.
