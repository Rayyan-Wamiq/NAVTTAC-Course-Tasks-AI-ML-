# %%
'''Syntax — The words are individually English words, but they are arranged in an order that does not follow English grammatical rules.
Pragmatics — The literal meaning is that the speaker feels very cold, but in context they are indirectly asking the other person to close the window.
Discourse — Understanding what “it” refers to requires using the relationship between the different parts of the sentence and the broader context.
Semantics — The word “bat” has multiple meanings, and the meaning is determined by the surrounding words and context.'''

# %%
'''Syntactically valid but semantically nonsensical:
“The silent purple mountain whispered loudly to the sleeping clock.”
Pragmatic meaning differs from literal meaning:
“Could you turn down the music?”
Literal meaning: Asking whether the person is capable of turning down the music.
Pragmatic meaning: Politely asking the person to turn down the music.
Two-sentence mini-passage:
“Maria gave Sarah the keys to the apartment. She thanked Maria and put them in her bag.”
Here, discourse-level understanding is needed to determine that “She” refers to Sarah, not Maria.'''

# %%
'''Word: “Bark”
Sentence 1: “The dog’s bark woke me up.” → Bark means the sound a dog makes.
Sentence 2: “The tree’s bark was rough.” → Bark means the outer covering of a tree.
An NLP system could figure out the intended sense by looking at the surrounding context. For example, words like “dog” and “woke” suggest that bark means a sound, while words like “tree” and “rough” suggest that it means the outer covering. Modern NLP models use patterns learned from large amounts of text to determine which meaning is most likely in context.'''

# %%
'''28. Future direction: Explainable AI

I think Explainable AI matters because people need to understand why an NLP system makes a particular decision. For example, if an AI rejects a job application, incorrectly flags an email as spam, or gives a medical recommendation, users should be able to understand what information influenced the result. Explainability can make NLP systems more trustworthy, transparent, and easier to improve, especially when they are used in important real-world situations.'''
