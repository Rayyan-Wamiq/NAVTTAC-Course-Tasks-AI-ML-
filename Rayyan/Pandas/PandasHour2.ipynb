# %%
import pandas as pd

s = pd.Series([23,34,45,56,67], index = ["Shampoo", "Milk", "Soap", "Surf", "Cream"])
print(s)
# Out:
# Shampoo    23
# Milk       34
# Soap       45
# Surf       56
# Cream      67
# dtype: int64

# %%
data = {
    "product": ["Milk", "Shampoo", "Surf"],
    "price": [250, 300, 220],
    "quantity": [2,4,5]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    product  price  quantity
# 0     Milk    250         2
# 1  Shampoo    300         4
# 2     Surf    220         5

# %%
df = pd.read_csv("Book1.csv")
print(df)
# Out:
#        Name  Age     City
# 0    Rayyan   21  Karachi
# 1     Qasim   22  Karachi
# 2    Muneeb   20  Karachi
# 3       Ali   23   Lahore
# 4  Sharjeel   20   Thatta
