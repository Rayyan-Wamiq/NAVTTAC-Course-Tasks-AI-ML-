# %%
import pandas as pd

data = {"name": ["Rayyan", "Qasim"], "Age": [21,23], "City": ["Karachi" , "Karachi"]}
df = pd.DataFrame(data)
print(df)
# Out:
#      name  Age     City
# 0  Rayyan   21  Karachi
# 1   Qasim   23  Karachi

# %%
"""
5.	For each of the following, decide whether NumPy or Pandas is the more natural tool, and briefly justify: (a) a large grid of pure sensor readings for fast math, (b) a customer database with names, emails, and purchase history, (c) a matrix used in a linear algebra calculation, (d) a CSV file downloaded from a government open-data website."""

"""
a) For fast math Numpy is better because numpy is made for fast numerical calculation and matrices which is pure for sensor readings.
b)
